# %%
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Echocardiogram.csv')

# %%
df.head()
# Out:
#    Case survival still-alive age-at-heart-attack pericardial-effusion  \
# 0     1       11           0                  71                    0
# 1     1       19           0                  72                    0
# 2     1       16           0                  55                    0
# 3     1       57           0                  60                    0
# 4     1       19           1                  57                    0
#
#   fractional-shortening    epss   lvdd wall-motion-score wall-motion-index  \
# 0                  0.26       9    4.6                14                 1
# 1                  0.38       6    4.1                14               1.7
# 2                  0.26       4   3.42                14                 1
# 3                 0.253  12.062  4.603                16              1.45
# 4                  0.16      22   5.75                18              2.25
#
#     mult  name group alive-at-1
# 0      1  name     1          0
# ...

# %% [markdown]
# #### Attribute-Concept Values used to fill up Incomplete Data !!
